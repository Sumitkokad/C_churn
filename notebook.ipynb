# %% [markdown]
# Preprocessing phase

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/customer_churn_data.csv")

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
# Filling this null values to increase the model accuarcy
df.isna().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %%
df['InternetService']=df['InternetService'].fillna("")

# %%
df.isna().sum()
# Out:
# CustomerID         0
# Age                0
# Gender             0
# Tenure             0
# MonthlyCharges     0
# ContractType       0
# InternetService    0
# TotalCharges       0
# TechSupport        0
# Churn              0
# dtype: int64

# %%
# Checking duplicated values

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Counting churn majority churn is yes so model is biased that learns only the majority
# data and neglate data so we fix this

df['Churn'].value_counts()
# Out:
# Churn
# Yes    883
# No     117
# Name: count, dtype: int64

# %% [markdown]
# Machine learning Phase

# %%
# Feature engineering is starts -->

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='object')

# %%
y=df[['Churn']]

# %%
y
# Out:
#     Churn
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4     Yes
# ..    ...
# 995   Yes
# 996   Yes
# 997   Yes
# 998   Yes
# 999   Yes
#
# [1000 rows x 1 columns]

# %%
x=df[['Age','Gender','Tenure','MonthlyCharges']]

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49    Male       4           88.35
# 1     43    Male       0           36.67
# 2     51  Female       2           63.79
# 3     60  Female       8          102.34
# 4     42    Male      32           69.01
# ..   ...     ...     ...             ...
# 995   42    Male      41           37.14
# 996   62    Male       9           80.93
# 997   51  Female      15          111.72
# 998   39    Male      68           65.67
# 999   50    Male       1           56.67
#
# [1000 rows x 4 columns]

# %%
# Encode the columns in the x and y data column like Gender and churn convert into numeric value

# %%
# For y churn means = 1 and not churn means = 0
y['Churn']=y['Churn'].apply(lambda x : 1 if x=='Yes' else 0)
# Out:
# /tmp/ipykernel_363/1376298929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Churn']=y['Churn'].apply(lambda x : 1 if x=='Yes' else 0)

# %%
y
# Out:
#      Churn
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      1
# 999      1
#
# [1000 rows x 1 columns]

# %%
# Now encode the x columns like Gender for female = 1 for Male = 0

x['Gender']=x['Gender'].apply(lambda x: 1 if x=='Female' else 0)
# Out:
# /tmp/ipykernel_363/1187319645.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Gender']=x['Gender'].apply(lambda x: 1 if x=='Female' else 0)

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 807   40       1      11           45.72
# 630   28       1      32           84.32
# 508   45       0      14           53.37
# 675   37       1       3           78.98
# 11    40       1      19           36.18
# ..   ...     ...     ...             ...
# 78    45       0      22          103.34
# 996   62       0       9           80.93
# 687   41       1      33           50.35
# 765   37       1       1           48.93
# 43    41       0      10           88.87
#
# [800 rows x 4 columns]

# %%
y_train
# Out:
#      Churn
# 807      1
# 630      1
# 508      0
# 675      1
# 11       0
# ..     ...
# 78       1
# 996      1
# 687      1
# 765      1
# 43       1
#
# [800 rows x 1 columns]

# %%
# We use scale the data using standard scaler
from sklearn.preprocessing import StandardScaler

# %%
# Initialize the standard scaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(x_train)

# %%
# # Save the trained scaler object to a file so it can be reused later without retraining
import joblib
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
# X test values are also scaled

X_test=scaler.fit_transform(x_test)

# %%
X_train
# Out:
# array([[-0.47200595,  0.93933644, -0.44065994, -1.09236466],
#        [-1.69567788,  0.93933644,  0.65027536,  0.41242759],
#        [ 0.03785735, -1.06458129, -0.28481204, -0.7941351 ],
#        ...,
#        [-0.37003329,  0.93933644,  0.70222466, -0.91186755],
#        [-0.77792394,  0.93933644, -0.96015294, -0.9672252 ],
#        [-0.37003329, -1.06458129, -0.49260924,  0.58980595]])

# %%
X_test
# Out:
# array([[ 0.01489363,  0.87744601,  1.57447608, -0.62986862],
#        [-1.73125603,  0.87744601,  0.46917235, -1.08933166],
#        [-0.60139448, -1.13967126, -0.57795751, -0.85182581],
#        [-0.4986798 ,  0.87744601,  1.69082384,  0.6085825 ],
#        [ 0.220323  ,  0.87744601, -0.46160974, -1.75364835],
#        [-0.60139448, -1.13967126, -0.92700079,  0.52811816],
#        [-0.19053574, -1.13967126, -0.86882691,  0.262236  ],
#        [-0.70410917,  0.87744601,  0.76004175,  0.7232539 ],
#        [-0.60139448,  0.87744601, -0.17074034, -0.45494615],
#        [ 1.35018454, -1.13967126, -0.57795751,  0.99107965],
#        [-0.80682386, -1.13967126,  2.03986713, -0.59954873],
#        [-1.42311197,  0.87744601,  0.64369399, -0.72510419],
#        [-0.08782106, -1.13967126, -0.92700079,  0.19498803],
#        [ 0.01489363,  0.87744601,  0.23647683,  1.001575  ],
#        [ 1.24746986,  0.87744601, -0.69430527, -0.79157473],
# ...

# %% [markdown]
# *Now Both the training and testing data is scaled and we can use this data to train our model and make predictions*

# %%
# This function is used to check the performance of the model
# Importing the classification model
from sklearn.metrics import accuracy_score
# It shows the accuracy in 0 and 1-> 1 is better than 0
# This function is used to check the performance of the model by calculating the accuracy score and printing it in a formatted way
def modelperformance(predictions):
    print("Accaracy Score of the model is: {:.2f}".format(accuracy_score(y_test, predictions)))

# %%
# We already check the best model is support vector machine for this dataset and this working so we import basially the support vector machine algorithm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
import joblib

# %%
sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
svm = SVC(probability=True, class_weight='balanced')

param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

grid_svm = GridSearchCV(svm, param_grid, cv=5, scoring='f1')

grid_svm.fit(X_train_res, y_train_res)

best_model = grid_svm.best_estimator_
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
y_pred = best_model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.67      0.28        15
#            1       0.97      0.75      0.84       185
#
#     accuracy                           0.74       200
#    macro avg       0.57      0.71      0.56       200
# weighted avg       0.91      0.74      0.80       200

# %%
modelperformance(y_pred)
# Out:
# Accaracy Score of the model is: 0.74

# %%
# model saved sucessfully
joblib.dump(best_model, 'best_model.pkl')

print("\nModel saved successfully ✅")
# Out:
# Model saved successfully ✅
